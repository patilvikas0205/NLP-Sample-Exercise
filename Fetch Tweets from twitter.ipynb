# %%
import tweepy

# %%
#Import the classes

# %%
#from tweepy import OAuthHandler
#from tweepy import Stream
#from tweepy.streaming import StreamListener

# %%
auth = tweepy.auth.OAuthHandler("API KEY", "API Secrte")
auth.set_access_token("Access Token ", "Token Secrete")
api = tweepy.API(auth)

# %%
api

# %%
def get_tweets(api, keywords, count):
  return api.search(q=keywords, result_type='recent', lang='en', count=count)
tweets = get_tweets(api, ['modi',"covid", "india", "US"],1000)
#print(tweets)

# %%
for tweet in tweets:
    print(tweet)
# Out:
# Status(_api=<tweepy.api.API object at 0x000001B82CBA30D0>, _json={'created_at': 'Thu Jan 07 09:13:51 +0000 2021', 'id': 1347109180071583750, 'id_str': '1347109180071583750', 'text': 'RT @Anjita97: @paulagnimitra1 @blsanthosh @amitmalviya @VanathiBJP @narendramodi @AmitShah @JPNadda @smritiirani @KailashOnline @shivprakas…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'Anjita97', 'name': 'অঞ্জিতা', 'id': 1252243503037517824, 'id_str': '1252243503037517824', 'indices': [3, 12]}, {'screen_name': 'paulagnimitra1', 'name': 'Agnimitra Paul Official', 'id': 1121279474073362432, 'id_str': '1121279474073362432', 'indices': [14, 29]}, {'screen_name': 'blsanthosh', 'name': 'B L Santhosh', 'id': 1065563383, 'id_str': '1065563383', 'indices': [30, 41]}, {'screen_name': 'amitmalviya', 'name': 'Amit Malviya', 'id': 95588504, 'id_str': '95588504', 'indices': [42, 54]}, {'screen_name': 'VanathiBJP', 'name': 'Vanathi Srinivasan', 'id': 974143844, '
# ...

# %%
for tweet in tweets:
    print(tweet.text)
# Out:
# RT @RahulGandhi: 23 lakh people in the world have already received Covid vaccinations.
#
# China, US, UK, Russia have started...
#
# India ka num…
# RT @BINDUTKK: Modi ji knows..and we all shd be prepared for this world shifting political coup kind of atmosphere created by Whichever Vest…
# RT @BINDUTKK: Modi ji knows..and we all shd be prepared for this world shifting political coup kind of atmosphere created by Whichever Vest…
# RT @BINDUTKK: Modi ji knows..and we all shd be prepared for this world shifting political coup kind of atmosphere created by Whichever Vest…
# RT @RahulGandhi: 23 lakh people in the world have already received Covid vaccinations.
#
# China, US, UK, Russia have started...
#
# India ka num…
# RT @RahulGandhi: 23 lakh people in the world have already received Covid vaccinations.
#
# China, US, UK, Russia have started...
#
# India ka num…
# RT @RahulGandhi: 23 lakh people in the world have already received Covid vaccinations.
#
# ...

# %%
tweet_list=[]
for tweet in tweets:
    tweet_list.append(tweet.text)

# %%
tweet_list
# Out:
# ['RT @RahulGandhi: 23 lakh people in the world have already received Covid vaccinations.\n\nChina, US, UK, Russia have started...\n\nIndia ka num…',
#  'RT @BINDUTKK: Modi ji knows..and we all shd be prepared for this world shifting political coup kind of atmosphere created by Whichever Vest…',
#  'RT @BINDUTKK: Modi ji knows..and we all shd be prepared for this world shifting political coup kind of atmosphere created by Whichever Vest…',
#  'RT @BINDUTKK: Modi ji knows..and we all shd be prepared for this world shifting political coup kind of atmosphere created by Whichever Vest…',
#  'RT @RahulGandhi: 23 lakh people in the world have already received Covid vaccinations.\n\nChina, US, UK, Russia have started...\n\nIndia ka num…',
#  'RT @RahulGandhi: 23 lakh people in the world have already received Covid vaccinations.\n\nChina, US, UK, Russia have started...\n\nIndia ka num…',
# ...

# %%
len(tweet_list)
# Out:
# 100

# %%
import pandas as pd

# %%
tweet_data=pd.DataFrame()
tweet_data["tweet"]=tweet_list
tweet_data
# Out:
#                                                 tweet
# 0   Modi ji knows..and we all shd be prepared for ...
# 1   #GoHeadlines:\n'Democratic process cannot be a...
# 2   RT @RahulGandhi: 23 lakh people in the world h...
# 3   @modi_moga #UnJustice In Maharashtra at Intern...
# 4   If Trump-Bhakts have the resolve to storm the ...
# ..                                                ...
# 95  RT @RahulGandhi: 23 lakh people in the world h...
# 96  via @PerilOfAfrica #Religion #InternationalNew...
# 97  PM Narendra Modi had the highest approval rati...
# 98  RT @RahulGandhi: 23 lakh people in the world h...
# 99  PM Narendra Modi had the highest approval rati...
#
# [100 rows x 1 columns]

# %%
import pandas as pd
import tweepy
import time

# %%
auth = tweepy.auth.OAuthHandler("JAMAnsabiudAGGDewbLiF1cvj", "qlRqEGDuGrpRXVA9wVCaHDnHRa2qsouu0GvGwH0hvZ9Lhkn2oC")
auth.set_access_token("1347068869018406915-3BNm4bZJOaqWepS47MyZ6V81F8ii7Z", "oeZmoAvk4eO3gFGDwh54XfoY3ktki2FqRg8OaTmT9Nowp")
api = tweepy.API(auth)

# %%
api

# %%
def username_tweets_to_csv(username,count):
    try:      
        tweets = tweepy.Cursor(api.user_timeline, id=username).items(count)

       
        tweets_list = [[tweet.created_at, tweet.id, tweet.text] for tweet in tweets]
        
       
        tweets_df = pd.DataFrame(tweets_list,columns=['Datetime', 'Tweet Id', 'Text'])

      
        tweets_df.to_csv('{}-tweets.csv'.format(username), sep=',', index = False)

    except BaseException as e:
          print('failed on_status,',str(e))
          time.sleep(3)

# %%
username = '@PawarSpeaks'
count = 150

username_tweets_to_csv(username, count)

# %%
tweets = []
tweets = tweepy.Cursor(api.user_timeline, id=username).items(count)
  
tweets_list = [[tweet.created_at, tweet.id, tweet.text] for tweet in tweets]
       
tweets_df = pd.DataFrame(tweets_list,columns=['Datetime', 'Tweet Id', 'Text'])
      
tweets_df.to_csv('{}-tweets.csv'.format(username), sep=',', index = False)

# %%
tweets.page_iterator

# %%
tweets_list
# Out:
# [[datetime.datetime(2021, 1, 6, 5, 16, 28),
#   1346687055183499264,
#   'सुमारे ४० वर्षांपूर्वी माझ्या स्वीय सहाय्यक पदाची जबाबदारी सचोटी आणि प्रामाणिकपणे सांभाळणारे ९० वर्षांचे श्रीपाद… https://t.co/xNE62vlfVD'],
#  [datetime.datetime(2021, 1, 6, 3, 0),
#   1346652709949116416,
#   'सांविधानिक मूल्यांना जपणाऱ्या व लोकशाही टिकवण्यासाठी सजग, सतर्क, निर्भीड व निष्पक्ष पत्रकारितेचा वारसा बाळगणाऱ्या स… https://t.co/6iRJAOhZV7'],
#  [datetime.datetime(2021, 1, 4, 3, 40, 1),
#   1345938004334923776,
#   'काँग्रेसचे ज्येष्ठ नेते व माजी सहकार मंत्री विलासकाका पाटील उंडाळकर यांचे निधन दुःखदायक आहे.\nत्यांच्या निधनाने प… https://t.co/yR0kIK2F7Z'],
#  [datetime.datetime(2021, 1, 3, 4, 44, 47),
#   1345591916600074240,
#   'क्रांतिज्योती सावित्रीमाई फुले यांनी स्त्री शिक्षणासाठी आयुष्य वेचले. जोतीबा फुलेंच्या निधनानंतर सत्यशोधक समाजाचे… https://t.co/VeAqa3jll3'],
#  [datetime.datetime(2021, 1, 2, 10, 23, 35),
#   1345314792001609729,
# ...
